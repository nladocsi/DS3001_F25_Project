# %% [markdown]
# <a href="https://colab.research.google.com/github/nladocsi/DS3001_F25_Project/blob/main/final_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Milestone 3
# ## Setting Up and Uploading Data

# %%
import numpy as np
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./adult24.csv')
print(df.shape, '\n')
df.head()
# Out:
# (32629, 630)
#    RATCAT_A  INCTCFLG_A  IMPINCFLG_A  PPSU  PSTRAT  WLKLEISTC_A  WLKTRANTC_A  \
# 0         9           0            2     2     122          NaN          NaN
# 1         8           0            0     2     122         20.0          NaN
# 2         7           0            0     2     122         30.0          NaN
# 3        12           0            0     2     122         10.0          NaN
# 4        14           0            0     1     115          NaN          NaN
#
#    HISPALLP_A  RACEALLP_A  ANYDIFF_A  ...  LSATIS4_A  PHSTAT_A  HHSTAT_A  \
# 0           2           1          2  ...          1         1         1
# 1           2           1          2  ...          2         2         1
# 2           2           1          1  ...          1         2         1
# 3           2           1          1  ...          2         3         1
# 4           3           2          1  ...          2         3         1
#
#    INTV_MON  RECTYPE  IMPNUM_A  AVGNUMCIG_A     WTFA_A      HHX  POVRATTC_A
# 0         1       10         1           30   5780.565  H067658        2.82
# 1         1       10         1           20   3994.244  H076577        2.01
# 2         1       10         1           20   6636.755  H019335        1.90
# 3         1       10         1           01  13767.420  H012701        4.48
# 4         1       10         1          NaN  18880.030  H049678        6.37
#
# [5 rows x 630 columns]

# %% [markdown]
# ## Cleaning Data

# %%
#Keeping Only Columns of Interest
cols = ['GESDIB_A', 'PREDIB_A', 'DIBEV_A',
        'FDSRUNOUT_A', 'FDSLAST_A',
        'FDSHUNGRY_A','FSNAP12M_A', 'FSNAP30D_A', 'SEX_A', 'REGION', 'RACEALLP_A',
        'RATCAT_A', 'EDUCP_A', 'PHSTAT_A', 'WLKLEIS_A', 'BMICAT_A', 'HYPEV_A','CHLEV_A','AGEP_A']
df = df[cols]
print(df.shape, '\n')
df.head()
# Out:
# (32629, 19)
#    GESDIB_A  PREDIB_A  DIBEV_A  FDSRUNOUT_A  FDSLAST_A  FDSHUNGRY_A  \
# 0       NaN         2        2            3          3          NaN
# 1       NaN         2        2            3          3          NaN
# 2       NaN         2        2            3          3          NaN
# 3       NaN         2        2            3          2          2.0
# 4       2.0         2        2            3          3          NaN
#
#    FSNAP12M_A  FSNAP30D_A  SEX_A  REGION  RACEALLP_A  RATCAT_A  EDUCP_A  \
# 0           2         NaN      1       3           1         9        5
# 1           2         NaN      1       3           1         8        5
# 2           2         NaN      1       3           1         7        5
# 3           2         NaN      1       3           1        12        4
# 4           2         NaN      2       3           2        14        9
#
#    PHSTAT_A  WLKLEIS_A  BMICAT_A  HYPEV_A  CHLEV_A  AGEP_A
# 0         1        2.0         3        2        2      49
# 1         2        1.0         3        1        2      53
# 2         2        1.0         4        1        2      82
# 3         3        1.0         3        2        2      42
# 4         3        2.0         3        2        2      38

# %%
#Creating Food Insecurity Variable
df[["FSNAP12M_A", "FSNAP30D_A", "FDSRUNOUT_A","FDSLAST_A", "FDSHUNGRY_A"]] = df[["FSNAP12M_A", "FSNAP30D_A", "FDSRUNOUT_A", "FDSLAST_A", "FDSHUNGRY_A"]].replace([7, 8, 9], np.nan)

df["FOOD_INS"] = np.where((df[["FSNAP12M_A", "FSNAP30D_A", "FDSRUNOUT_A", "FDSLAST_A", "FDSHUNGRY_A"]] == 1).any(axis=1), 1,
    np.where((df[["FDSRUNOUT_A","FDSLAST_A"]] == 2).any(axis=1), 1,
             np.where((df[["FSNAP12M_A", "FSNAP30D_A", "FDSHUNGRY_A"]] == 2).any(axis=1),0,
                      np.where((df[["FSNAP12M_A", "FSNAP30D_A"]] == 3).any(axis=1),0, np.nan))))
df = df.drop(columns=["FSNAP12M_A", "FSNAP30D_A", "FDSRUNOUT_A","FDSLAST_A", "FDSHUNGRY_A"])
df.head()
# Out:
#    GESDIB_A  PREDIB_A  DIBEV_A  SEX_A  REGION  RACEALLP_A  RATCAT_A  EDUCP_A  \
# 0       NaN         2        2      1       3           1         9        5
# 1       NaN         2        2      1       3           1         8        5
# 2       NaN         2        2      1       3           1         7        5
# 3       NaN         2        2      1       3           1        12        4
# 4       2.0         2        2      2       3           2        14        9
#
#    PHSTAT_A  WLKLEIS_A  BMICAT_A  HYPEV_A  CHLEV_A  AGEP_A  FOOD_INS
# 0         1        2.0         3        2        2      49       0.0
# 1         2        1.0         3        1        2      53       0.0
# 2         2        1.0         4        1        2      82       0.0
# 3         3        1.0         3        2        2      42       1.0
# 4         3        2.0         3        2        2      38       0.0

# %%
#Creating one variable for diabetes
df[["PREDIB_A", "GESDIB_A", "DIBEV_A"]] = df[["PREDIB_A", "GESDIB_A", "DIBEV_A"]].replace([7, 8, 9], np.nan)

df["DIAB_ANY"] = np.where((df[["PREDIB_A", "GESDIB_A", "DIBEV_A"]] == 1).any(axis=1), 1,
    np.where((df[["PREDIB_A", "GESDIB_A", "DIBEV_A"]] == 2).any(axis=1), 0, np.nan))
df = df.drop(columns=["PREDIB_A", "GESDIB_A", "DIBEV_A"])

df.head()
# Out:
#    SEX_A  REGION  RACEALLP_A  RATCAT_A  EDUCP_A  PHSTAT_A  WLKLEIS_A  \
# 0      1       3           1         9        5         1        2.0
# 1      1       3           1         8        5         2        1.0
# 2      1       3           1         7        5         2        1.0
# 3      1       3           1        12        4         3        1.0
# 4      2       3           2        14        9         3        2.0
#
#    BMICAT_A  HYPEV_A  CHLEV_A  AGEP_A  FOOD_INS  DIAB_ANY
# 0         3        2        2      49       0.0       0.0
# 1         3        1        2      53       0.0       0.0
# 2         4        1        2      82       0.0       0.0
# 3         3        2        2      42       1.0       0.0
# 4         3        2        2      38       0.0       0.0

# %%
#Converting 7-9 reponse variables to nan

nan_cols =["SEX_A", "REGION","RACEALLP_A", "RATCAT_A", "EDUCP_A", "PHSTAT_A", "WLKLEIS_A"]
df[nan_cols] = df[nan_cols].replace([7, 8, 9], np.nan)

# %%
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
print("\nSummary Statistics for Numeric Columns:\n")
print(df[numeric_cols].describe())
# Out:
# Summary Statistics for Numeric Columns:
#
#               SEX_A        REGION    RACEALLP_A      RATCAT_A       EDUCP_A  \
# count  32624.000000  32629.000000  30929.000000  25669.000000  18503.000000
# mean       1.540676      2.702596      1.385011     10.095524      5.107874
# std        0.498350      1.012700      0.925114      4.434227      8.598595
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      2.000000      1.000000      6.000000      4.000000
# 50%        2.000000      3.000000      1.000000     12.000000      4.000000
# 75%        2.000000      3.000000      1.000000     14.000000      5.000000
# max        2.000000      4.000000      6.000000     14.000000     99.000000
#
#            PHSTAT_A     WLKLEIS_A      BMICAT_A       HYPEV_A       CHLEV_A  \
# count  32613.000000  31302.000000  32629.000000  32629.000000  32629.000000
# mean       2.479962      1.396620      3.097582      1.633118      1.687088
# std        1.054828      0.489204      1.163760      0.541155      0.599415
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      1.000000      2.000000      1.000000      1.000000
# 50%        2.000000      1.000000      3.000000      2.000000      2.000000
# 75%        3.000000      2.000000      4.000000      2.000000      2.000000
# max        5.000000      2.000000      9.000000      9.000000      9.000000
#
#              AGEP_A      FOOD_INS      DIAB_ANY
# count  32629.000000  31219.000000  32609.000000
# mean      53.453278      0.197572      0.240792
# std       18.673458      0.398174      0.427571
# min       18.000000      0.000000      0.000000
# 25%       37.000000      0.000000      0.000000
# 50%       55.000000      0.000000      0.000000
# 75%       69.000000      0.000000      0.000000
# max       99.000000      1.000000      1.000000

# %%
#Final code to run at end of data manipulation

df.to_csv('diabetes_clean.csv', index=False)

# %% [markdown]
# ## Visualizing the data

# %%
sns.countplot(data=df, x="DIAB_ANY")
plt.title("Diabetes Prevalence")
plt.xlabel("Diabetes Status (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %%
counts = df['DIAB_ANY'].value_counts().sort_index()
percentages = counts / counts.sum() * 100

print(f"No Diabetes (0): {percentages[0]:.2f}%")
print(f"Diabetes (1): {percentages[1]:.2f}%")
# Out:
# No Diabetes (0): 75.92%
# Diabetes (1): 24.08%

# %%
df[["SEX_A"]] = df[["SEX_A"]].replace([7, 8, 9], np.nan)

sns.catplot(
    data=df,
    x="SEX_A",
    hue="DIAB_ANY",
    kind="count"
)
plt.title("Diabetes by Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
df_sex_diab = df[["SEX_A", "DIAB_ANY"]].dropna()

sex_diabetes_percent = (df_sex_diab.groupby("SEX_A")["DIAB_ANY"].mean() * 100)

print("Percent with Diabetes by Sex:")
print(f"Male (1): {sex_diabetes_percent[1]:.2f}%")
print(f"Female (2): {sex_diabetes_percent[2]:.2f}%")
# Out:
# Percent with Diabetes by Sex:
# Male (1): 22.06%
# Female (2): 25.80%

# %%
plt.figure(figsize=(8,6))
corr = df[['AGEP_A','BMICAT_A','CHLEV_A','HYPEV_A','DIAB_ANY']].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Building Model
# ### Setting up Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

df = df.dropna(subset=['DIAB_ANY'])
N = df.shape[0]
df = df.sample(frac=1, random_state=100).reset_index(drop=True)
train_size=int(.8*N)
df_train = df.iloc[:train_size, :].copy()
df_test = df.iloc[train_size:, :].copy()

y_train = df_train['DIAB_ANY']
X_train = df_train.drop('DIAB_ANY',axis=1)

y_test = df_test['DIAB_ANY']
X_test = df_test.drop('DIAB_ANY',axis=1)

#drop_variables = ['DIBTYPE_A', 'DIBAGETC_A']
#X_train = X_train.drop(drop_variables, axis=1)
#X_test = X_test.drop(drop_variables, axis=1)

min_samp = max(1, int(0.01 * len(df_train)))

def quick_tree(df,depth=15):
    df_t = df_train.sample(n=df.shape[0],replace=True)
    y_train = df_t['DIAB_ANY']
    X_train = df_t.drop('DIAB_ANY',axis=1)

    #drop_variables = ['DIBTYPE_A', 'DIBAGETC_A']
   # X_train = X_train.drop(drop_variables, axis=1)

    cart = tree.DecisionTreeClassifier(max_depth=depth, min_samples_leaf=min_samp)
    cart = cart.fit(X_train, y_train)

    plt.figure(figsize=(10,10))
    tree.plot_tree(cart,feature_names=X_train.columns.to_list(),filled=True)
    plt.show()

    y_hat = cart.predict(X_test)

    tab = pd.crosstab(y_test, y_hat, rownames=['Actual'], colnames=['Predicted'])
    tab = tab.reindex([0, 1])
    print('Confusion Matrix: ')
    print(tab)

    TP = tab.iloc[0,0]
    TN = tab.iloc[1,1]
    FP = tab.iloc[1,0]
    FN = tab.iloc[0,1]

    TPR = TP/(TP+FN)
    TNR = TN/(TN+FP)

    print('True Positive Rate: ', round(TPR, 3))
    print('True Negative Rate: ', round(TNR, 3))

    accuracy = accuracy_score(y_test, y_hat)
    print('Accuracy: ', round(accuracy, 3))

    return y_hat, tab, accuracy, TPR, TNR

# %%
y_hat_1 = quick_tree(df)
# Out:
# Confusion Matrix:
# Predicted   0.0  1.0
# Actual
# 0          4612  335
# 1          1071  504
# True Positive Rate:  0.932
# True Negative Rate:  0.32
# Accuracy:  0.784

# %%
y_hat_2 = quick_tree(df)
# Out:
# Confusion Matrix:
# Predicted   0.0  1.0
# Actual
# 0          4591  356
# 1          1068  507
# True Positive Rate:  0.928
# True Negative Rate:  0.322
# Accuracy:  0.782

# %% [markdown]
# ### Testing Max Depth Values

# %%
y_test = df_test['DIAB_ANY']
X_test = df_test.drop('DIAB_ANY',axis=1)
#X_test = X_test.drop(['DIBTYPE_A', 'DIBAGETC_A'], axis=1)

y_train = df_train['DIAB_ANY']
X_train = df_train.drop('DIAB_ANY',axis=1)
#X_train = X_train.drop(['DIBTYPE_A', 'DIBAGETC_A'], axis=1)

depth_values = [5, 10, 15, 20]
results = []

for depth in depth_values:
    min_samp = max(1, int(0.01 * len(df_train)))

    cart = tree.DecisionTreeClassifier(max_depth=depth,
                                      min_samples_leaf=min_samp,
                                      random_state=0)
    cart = cart.fit(X_train, y_train)
    y_pred = cart.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    results.append({'max depth':depth,
                    'Accuracy':accuracy})

dfresults = pd.DataFrame(results)
print(dfresults)
# Out:
#    max depth  Accuracy
# 0          5  0.784729
# 1         10  0.786415
# 2         15  0.786415
# 3         20  0.786415

# %% [markdown]
# ### Bootstrap Aggregation

# %%
T = 1000
m_depth =10

N_test = X_test.shape[0]
acc = np.zeros(1000)
y_test_hat = np.zeros((1000, N_test))

# %%
for s in range(T):
  df_s = df_train.sample(frac=1, replace=True)
  X_s = df_s.drop(columns='DIAB_ANY', axis=1)
  y_s = (df_s['DIAB_ANY'])

  #X_s = X_s.drop(drop_variables, axis=1)

  cart = tree.DecisionTreeClassifier(max_depth=m_depth, min_samples_leaf=min_samp)
  cart = cart.fit(X_s, y_s)

  y_hat = cart.predict(X_test)
  acc[s] = accuracy_score(y_test, y_hat)
  y_test_hat[s,:] = y_hat

y_ensemble = np.mean(y_test_hat, axis=0).astype(int)
accuracy_ensemble = accuracy_score(y_test, y_ensemble)
print('Accuracy: ', round(accuracy_ensemble, 3))
# Out:
# Accuracy:  0.767

# %%
ax = sns.kdeplot(x = acc, fill = True, color = "blue", alpha = 0.1)
ax.axvline(x = accuracy_ensemble)

print(np.quantile(acc,1))
print("2.5% and 97.5% accuracy quantiles:",
      np.quantile(acc, [0.025, 0.975]))
# Out:
# 0.7885617908616989
# 2.5% and 97.5% accuracy quantiles: [0.77736891 0.78702852]

# %% [markdown]
# ## Random Forests

# %%
y_train.head()
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    1.0
# Name: DIAB_ANY, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth=10, n_estimators=200, random_state=0)
rf.fit(X_train, y_train)

y_hat_rf = rf.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_hat_rf)
print('Accuracy: ', round(rf_accuracy, 3))

feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns )
feature_importances.sort_values().plot(kind='barh')
plt.title('Feature Importance')
plt.xlabel('Mean decrease in impurity')
plt.show()
# Out:
# Accuracy:  0.788
